# %% [markdown]
# ![title](https://www.kolonbenit.com/common/images/logo.gif)
#
# # Kolon Benit BigData Analytics Team
# --------------------------------------
# ## SAS Viya, Python Programming, 2019.08.02
# ### Example00 - How to Get CAS Action Documentation within Python-swat
# --------------------------------------
# Austin Rho (Shin Seok),
# - contact : ssrho@kolon.com, injoyer@yonsei.ac.kr
# --------------------------------------

# %%
# Load the swat package and turn off note messages
import swat
swat.options.cas.print_messages = False


host = "http://192.168.10.17/cas-shared-default-http/"
port = 8777
username = 'viya_kolon01'
password = 'viya'

# set the connection: host, port, username, password
s = swat.CAS(host, port, username, password)

# %% [markdown]
# ### What are the default loaded actionsets?

# %%
# list all loaded actionsets
s.builtins.actionSetInfo()
# Out:
# [setinfo]
#
#  Action set information
#
#           actionset               label  loaded  extension   version  \
#  0    accessControl     Access Controls       1     tkacon  3.04.000
#  1    accessControl     Access Controls       1    casmeta  3.04.000
#  2         builtins            Builtins       1  tkcasablt  3.04.000
#  3    configuration   Server Properties       1   tkcascfg  3.04.000
#  4   dataPreprocess     Data Preprocess       1    tktrans  3.04.000
#  5         dataStep           DATA Step       1   datastep  3.04.000
#  6       percentile          Percentile       1   tkcasptl  3.04.000
#  7           search              Search       1     casidx  3.04.000
#  8          session     Session Methods       1   tkcsessn  3.04.000
#  9      sessionProp  Session Properties       1   tkcstate  3.04.000
#  10          simple    Simple Analytics       1   tkimstat  3.04.000
#  11           table              Tables       1   tkcastab  3.04.000
#
#     product_name
# ...

# %% [markdown]
# ### What are the available actions for each actionset?

# %%
# list each actionset with available actions as an ordered dict
s.help()
# Out:
# [accessControl]
#
#                       name                                        description
#  0   accessPersonalCaslibs  Provides administrative access to all personal...
#  1              assumeRole                                     Assumes a role
#  2                dropRole                                Relinquishes a role
#  3             showRolesIn                    Shows the currently active role
#  4        showRolesAllowed         Shows the roles that a user is a member of
#  5                isInRole                    Shows whether a role is assumed
#  6            isAuthorized                 Shows whether access is authorized
#  7     isAuthorizedActions      Shows whether access is authorized to actions
#  8      isAuthorizedTables       Shows whether access is authorized to tables
#  9     isAuthorizedColumns      Shows whether access is authorized to columns
#  10      listAllPrincipals  Lists all principals that have explicit access...
# ...

# %% [markdown]
# ### I see an action that I need, how do I see the inputs?

# %%
# session.actionset.action
help(s.dataPreprocess.impute)
# Out:
# Help on datapreprocess.Impute in module swat.cas.actions object:
#
# class datapreprocess.Impute(CASAction)
#  |  Performs data matrix (variable) imputation
#  |
#  |  Parameters
#  |  ----------
#  |  table : dict or CASTable
#  |      specifies the table name, caslib, and other common parameters.
#  |
#  |      table.name : string or CASTable
#  |          specifies the name of the table to use.
#  |
#  |      table.caslib : string, optional
#  |          specifies the caslib that contains the table that you want to
#  |          use with the action. By default, the active caslib is used.
#  |          Specify a value only if you need to access a table from a
#  |          different caslib.
#  |
#  |      table.where : string, optional
#  |          specifies an expression for subsetting the input data.
#  |
#  |      table.groupby : list of dicts, optional
#  |          specifies the names of the variables to use for grouping
#  |          results.
#  |
# ...

# %% [markdown]
# ### What I need to do is in an actionset that's not loaded, how do I see all available actionsets?

# %%
# list all of the actionsets, whether they are loaded or not
s.builtins.actionSetInfo(all = True)
# Out:
# [setinfo]
#
#  Action set information
#
#                     actionset               label  loaded     extension  \
#  0                     access                           0        tkacon
#  1              accessControl     Access Controls       1       casmeta
#  2                aggregation                           0      tkcasagg
#  3                     astore                           0        astore
#  4                      audio                           0         audio
#  5                   autotune                           0      optminer
#  6      bayesianNetClassifier                           0     tkcasbnet
#  7                bioMedImage                           0   biomedimage
#  8                   boolRule                           0        casblr
#  9                   builtins            Builtins       1     tkcasablt
#  10               cardinality                           0   cardinality
# ...

# %% [markdown]
# ### Enable help on non previously loaded actionset and list newly available actions

# %%
# load in new actionset
s.builtins.loadActionSet('decisionTree')

# get help again
s.help().decisionTree
# Out:
#            name                                        description
# 0    dtreeTrain                             Trains a decision tree
# 1    dtreeScore         Scores a table using a decision tree model
# 2    dtreeSplit                         Splits decision tree nodes
# 3    dtreePrune                              Prune a decision tree
# 4    dtreeMerge                         Merges decision tree nodes
# 5     dtreeCode  Generates DATA step scoring code from a decisi...
# 6   forestTrain                                    Trains a forest
# 7   forestScore                Scores a table using a forest model
# 8    forestCode  Generates DATA step scoring code from a forest...
# 9   gbtreeTrain                    Trains a gradient boosting tree
# 10  gbtreeScore  Scores a table using a gradient boosting tree ...
# 11   gbtreeCode  Generates DATA step scoring code from a gradie...

# %% [markdown]
# ### Let's see the arguments of a specific action that I now have loaded

# %%
help(s.decisionTree.gbtreeTrain)
# Out:
# Help on decisiontree.Gbtreetrain in module swat.cas.actions object:
#
# class decisiontree.Gbtreetrain(CASAction)
#  |  Trains a gradient boosting tree
#  |
#  |  Parameters
#  |  ----------
#  |  table : dict or CASTable
#  |      specifies the settings for an input table.
#  |
#  |      table.name : string or CASTable
#  |          specifies the name of the table to use.
#  |
#  |      table.caslib : string, optional
#  |          specifies the caslib that contains the table that you want to
#  |          use with the action. By default, the active caslib is used.
#  |          Specify a value only if you need to access a table from a
#  |          different caslib.
#  |
#  |      table.where : string, optional
#  |          specifies an expression for subsetting the input data.
#  |
#  |      table.computedvars : list of dicts, optional
#  |          specifies the names of the computed variables to create. Specify
# ...

# %%
s.session.endsession() # end the session
# Out:
# + Elapsed: 0.00526s, user: 0.00157s, sys: 0.00334s, mem: 0.978mb
